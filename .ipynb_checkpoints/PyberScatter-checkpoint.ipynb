# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
city_data = pd.read_csv("Resources/city_data.csv")
ride_data = pd.read_csv("Resources/ride_data.csv")
combined_data = pd.merge(city_data, ride_data, how='outer', on="city")

plot_data = combined_data
plot_data.head()
# Out:
#           city  driver_count   type             date   fare       ride_id
# 0  Richardfort            38  Urban   2/24/2018 8:40  13.93  5.628550e+12
# 1  Richardfort            38  Urban  2/13/2018 12:46  14.00  9.100500e+11
# 2  Richardfort            38  Urban  2/16/2018 13:52  17.92  8.206390e+11
# 3  Richardfort            38  Urban   2/1/2018 20:18  10.26  9.554940e+12
# 4  Richardfort            38  Urban   4/17/2018 2:26  23.00  7.200210e+11

# %%
urban_cities = plot_data[plot_data["type"]=="Urban"]
suburban_cities = plot_data[plot_data["type"]=="Suburban"]
rural_cities = plot_data[plot_data["type"]=="Rural"]

urban_ride_count = urban_cities.groupby(["city"]).count()["ride_id"]
urban_average = urban_cities.groupby(["city"]).mean()["fare"]
urban_drivers = urban_cities.groupby(["city"]).mean()["driver_count"]

suburban_ride_count = suburban_cities.groupby(["city"]).count()["ride_id"]
suburban_average = suburban_cities.groupby(["city"]).mean()["fare"]
suburban_drivers = suburban_cities.groupby(["city"]).mean()["driver_count"]

rural_ride_count = rural_cities.groupby(["city"]).count()["ride_id"]
rural_average = rural_cities.groupby(["city"]).mean()["fare"]
rural_drivers = rural_cities.groupby(["city"]).mean()["driver_count"]

# %%
plt.scatter(urban_ride_count, urban_average, s=10*urban_drivers, c="coral", edgecolor="b", marker="o", alpha=0.8, label="Urban")
plt.scatter(suburban_ride_count, suburban_average, s=10*suburban_drivers, c="aqua", edgecolor="b", marker="o", alpha=0.8, label="Suburban")
plt.scatter(rural_ride_count, rural_average, s=10*rural_drivers, c="orange", edgecolor="b", marker="o", alpha=0.8, label="Rural")

plt.ylim(15, 45)

plt.xlim(0, 45)

plt.title("Pybar Ride Sharing Data (2016)")

plt.legend()

plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides(Per City)")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#urban_cities = plot_data[plot_data["type"]=="Urban"]
#suburban_cities = plot_data[plot_data["type"]=="Suburban"]
#rural_cities = plot_data[plot_data["type"]=="Rural"]

#urban_fare_count = urban_cities["fare"].sum()
#suburban_fare_count = suburban_cities["fare"].sum()
#rural_fare_count = rural_cities["fare"].sum()

#total_fare_count = urban_fare_count + suburban_fare_count + rural_fare_count

#urban_fare_percent = (urban_fare_count / total_fare_count)
#suburban_fare_percent = (suburban_fare_count / total_fare_count)
#rural_fare_percent = (rural_fare_count / total_fare_count)

#slices = [urban_fare_count, suburban_fare_count, rural_fare_count]

#labels = ["Urban", "Suburban", "Rural"]

#colors = ["red", "blue", "yellow"]

#plt.pie(slices, labels=labels, colors=colors, autopct="%1.1f%%")

#plt.show()

# %%
#urban_cities = plot_data[plot_data["type"]=="Urban"]
#suburban_cities = plot_data[plot_data["type"]=="Suburban"]
#rural_cities = plot_data[plot_data["type"]=="Rural"]

#urban_ride_count = urban_cities["ride_id"].count()
#suburban_ride_count = suburban_cities["ride_id"].count()
#rural_ride_count = rural_cities["ride_id"].count()

#slices = [urban_ride_count, suburban_ride_count, rural_ride_count]

#labels = ["Urban", "Suburban", "Rural"]

#colors = ["red", "blue", "yellow"]

#plt.pie(slices, labels=labels, colors=colors, autopct="%1.1f%%")

#plt.show()

# %%
#urban_cities = plot_data[plot_data["type"]=="Urban"]
#suburban_cities = plot_data[plot_data["type"]=="Suburban"]
#rural_cities = plot_data[plot_data["type"]=="Rural"]

#urban_drive_count = urban_cities.groupby(["city"]).sum()["driver_count"]
#suburban_drive_count = suburban_cities.groupby(["city"]).sum()["driver_count"]
#rural_drive_count = rural_cities.groupby(["city"]).sum()["driver_count"]

#slices = [urban_drive_count, suburban_drive_count, rural_drive_count]

#labels = ["Urban", "Suburban", "Rural"]

#colors = ["red", "blue", "yellow"]

#plt.pie(slices, labels=labels, colors=colors)

#plt.show()
